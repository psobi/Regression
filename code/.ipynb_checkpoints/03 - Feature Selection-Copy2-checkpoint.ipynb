# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline

#import warnings
import pickle5 as pickle
#warnings.filterwarnings('ignore')

# %%
#from sklearn.model_selection import train_test_split, GridSearchCV
#from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
sns.set_style("whitegrid")
#Import data
import pickle5 as pickle

file_train_X = open("../data/fe_train_X","rb")
file_train_y = open("../data/fe_train_y","rb")

X_train = pickle.load(file_train_X)
y_train = pickle.load(file_train_y)

X_train.isnull().sum().sum() #No missing values
X_train.shape
# Out:
# (1460, 79)

# %%
X_ = X_train.copy()

X_["TotalBsmtFin"] = X_["BsmtFinSF1"] + X_["BsmtFinSF2"]
X_["TotalBath"] = X_["FullBath"] + 0.5*X_["HalfBath"] + X_["BsmtFullBath"] + 0.5*X_["BsmtHalfBath"]

#X_["TotalLivArea"] = X_["GrLivArea"] + X_["TotalBsmtFin"]
    
drop_columns = ['BsmtFinSF1','BsmtFinSF2','FullBath','HalfBath','BsmtFullBath','BsmtHalfBath', '1stFlrSF','2ndFlrSF','1stFlrSF','2ndFlrSF', 'GarageCars','GarageYrBlt']


X_fs = X_.drop(drop_columns, axis=1)
X_fs.columns
# Out:
# Index(['Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature',
#        'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtUnfSF', 'TotalBsmtSF',
#        'LowQualFinSF', 'GrLivArea', 'BedroomAbvGr', 'KitchenAbvGr',
#        'TotRmsAbvGrd', 'Fireplaces', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'LandSlope', 'SaleType', 'RoofStyle', 'Condition1',
#        'Electrical', 'LotConfig', 'Exterior1st', 'ExterQual', 'RoofMatl',
#        'Neighborhood', 'ExterCond', 'Heating', 'LotShape', 'SaleCondition',
#        'MasVnrType', 'Condition2', 'KitchenQual', 'Utilities', 'PavedDrive',
#        'Street', 'Foundation', 'Functional', 'HouseStyle', 'MSZoning',
#        'LandContour', 'BldgType', 'Exterior2nd', 'CentralAir', 'HeatingQC',
#        'TotalBsmtFin', 'TotalBath'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
model_test = Pipeline(steps=[('classifier', RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=8))])

m = model_test.fit(X_fs,y_train)
feats = m.named_steps["classifier"].feature_importances_
cols = X_fs.columns.values
len(cols),len(feats)

feature_importance = pd.DataFrame(data=feats, columns=['Feature Importance'])
feature_name = pd.DataFrame(data=cols, columns=['Feature Name'])

frames = [feature_importance, feature_name]

f = pd.concat(frames, axis=1, sort=False)
fi = f.sort_values(by=['Feature Importance'],ascending=False)
feature_name
##d['Feature Importance'].sum()
fi.to_excel("output_feature_importance_4.xlsx")
#1stFlrSF
fi['cum_sum'] = fi['Feature Importance'].cumsum()
fi['cum_perc'] = 100*fi['cum_sum']/fi['Feature Importance'].sum()
pd.options.display.max_rows
pd.set_option('display.max_rows', 100)
fi
# Out:
# C:\Users\pawel\Anaconda3\lib\site-packages\sklearn\pipeline.py:335: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     Feature Importance   Feature Name   cum_sum    cum_perc
# 25            0.127323      GrLivArea  0.127323   12.732262
# 17            0.109189    OverallQual  0.236512   23.651193
# 23            0.081418    TotalBsmtSF  0.317930   31.792963
# 47            0.064874      ExterQual  0.382804   38.280412
# 30            0.056727     GarageArea  0.439531   43.953121
# 19            0.053334      YearBuilt  0.492865   49.286518
# 70            0.039806      TotalBath  0.532671   53.267129
# 16            0.036566        LotArea  0.569238   56.923753
# 56            0.035363    KitchenQual  0.604600   60.460049
# 1             0.032336       BsmtQual  0.636937   63.693656
# 28            0.031254   TotRmsAbvGrd  0.668190   66.819010
# 20            0.027104   YearRemodAdd  0.695294   69.529365
# 15            0.023690    LotFrontage  0.718984   71.898381
# 32            0.022403    OpenPorchSF  0.741387   74.138708
# 69            0.022188   TotalBsmtFin  0.763575   76.357483
# 49            0.018569   Neighborhood  0.782144   78.214389
# 60            0.016212     Foundation  0.798356   79.835570
# 21            0.015603     MasVnrArea  0.813959   81.395919
# 22            0.015396      BsmtUnfSF  0.829355   82.935485
# 68            0.013477      HeatingQC  0.842832   84.283178
# 29            0.013037     Fireplaces  0.855869   85.586886
# 14            0.010485     MSSubClass  0.866354   86.635369
# 31            0.009849     WoodDeckSF  0.876203   87.620284
# 6             0.008733    FireplaceQu  0.884936   88.493575
# 7             0.008348     GarageType  0.893284   89.328393
# 4             0.007951   BsmtFinType1  0.901235   90.123469
# 8             0.006699   GarageFinish  0.907933   90.793335
# 3             0.006141   BsmtExposure  0.914074   91.407388
# 62            0.005666     HouseStyle  0.919740   91.974008
# 38            0.005173         MoSold  0.924913   92.491291
# 26            0.005078   BedroomAbvGr  0.929991   92.999105
# 18            0.005052    OverallCond  0.935043   93.504304
# 46            0.004912    Exterior1st  0.939955   93.995545
# 54            0.004726     MasVnrType  0.944682   94.468153
# 66            0.004282    Exterior2nd  0.948964   94.896375
# 39            0.003965         YrSold  0.952929   95.292913
# 52            0.003407       LotShape  0.956336   95.633567
# 65            0.003110       BldgType  0.959445   95.944542
# 64            0.002744    LandContour  0.962189   96.218933
# 45            0.002456      LotConfig  0.964645   96.464515
# 43            0.002413     Condition1  0.967058   96.705846
# 42            0.002411      RoofStyle  0.969469   96.946933
# 35            0.002308    ScreenPorch  0.971778   97.177762
# 27            0.002198   KitchenAbvGr  0.973975   97.397523
# 5             0.002086   BsmtFinType2  0.976062   97.606151
# 53            0.001933  SaleCondition  0.977994   97.799432
# 0             0.001918          Alley  0.979912   97.991185
# 33            0.001783  EnclosedPorch  0.981695   98.169501
# 41            0.001624       SaleType  0.983319   98.331875
# 61            0.001504     Functional  0.984823   98.482283
# 63            0.001472       MSZoning  0.986295   98.629468
# 48            0.001447       RoofMatl  0.987741   98.774126
# 40            0.001445      LandSlope  0.989186   98.918592
# 34            0.001430      3SsnPorch  0.990616   99.061552
# 12            0.001416          Fence  0.992031   99.203124
# 2             0.001361       BsmtCond  0.993392   99.339247
# 58            0.001163     PavedDrive  0.994555   99.455539
# 37            0.001116        MiscVal  0.995671   99.567130
# 50            0.000752      ExterCond  0.996424   99.642352
# 9             0.000651     GarageQual  0.997075   99.707496
# 13            0.000605    MiscFeature  0.997680   99.768035
# 44            0.000525     Electrical  0.998205   99.820545
# 11            0.000358         PoolQC  0.998564   99.856361
# 67            0.000348     CentralAir  0.998912   99.891156
# 59            0.000304         Street  0.999216   99.921577
# 51            0.000244        Heating  0.999460   99.945975
# 36            0.000166       PoolArea  0.999625   99.962536
# 55            0.000164     Condition2  0.999790   99.978952
# 24            0.000138   LowQualFinSF  0.999928   99.992795
# 10            0.000053     GarageCond  0.999981   99.998129
# 57            0.000019      Utilities  1.000000  100.000000

# %%
#fi['cum_perc']
ax = sns.barplot(x="Feature Name", y="cum_perc", data=fi)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
fi_subset = fi[fi['cum_perc'] <= 99.1]
fi_subset

cols_list = fi_subset['Feature Name'].tolist()

X_train_selected_features = X_[cols_list]

# %%
import pickle5 as pickle

file_mrd_train_X = open("../data/X_train_selected_features", "wb")

pickle.dump(X_train_selected_features,file_mrd_train_X)

file_mrd_train_X.close()

# %%
import seaborn as sns
#ax = sns.distplot(d)
ax = sns.barplot(x="Feature Name", y="Feature Importance", data=fi)
#ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
mean_squared_error(predictions_rf, test2[target])

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline            # don't forget this if you're using jupyter!

X = pd.read_csv("titanic_train.csv")
X = X[['Pclass', 'Age', 'Fare', 'Parch', 'SibSp', 'Survived']].dropna()
y = X.pop('Survived')

model = RandomForestClassifier()
model.fit(X, y)

(pd.Series(model.feature_importances_, index=X.columns)
   .nlargest(4)
   .plot(kind='barh'))
